# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
import joblib
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
file = os.path.join('C:/Users/manue/Downloads/', 'Reboiler_Raw_Data_With_Timestamps (1).xlsx')
df1 = pd.read_excel(file, header=0)
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1

# %%
df1 = df1.drop([
	'VAL356M003-Carga Motor',
], axis='columns')
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1

# %%
df1 = df1.rename(columns={
	'VAL356CI8017-Conductividad': 'Conductividad',
	'VAL356M014-Carga Motor': 'M014-Carga Motor',
	'VAL356M015-Carga Motor': 'M015-Carga Motor',
	'VAL356PI8026-Ind.Presión': 'Ind.Presión (PI8026)',
	'VAL356PIC8025-Ind.Presión': 'Ind.Presión (PIC8025)',
	'VAL356TI8015-Ind.Temperatura': 'Ind.Temperatura (TI8015)',
	'VAL356TIC8014-Ind.Temperatura': 'Ind.Temperatura (TIC8014)',
})
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1

# %%
df1 = df1
s = df1['Fecha']
df1['Fecha'] = pd.to_datetime(s, errors='coerce')

s = df1['M014-Carga Motor']
df1['M014-Carga Motor'] = pd.to_numeric(s, errors='coerce')

s = df1['M015-Carga Motor']
df1['M015-Carga Motor'] = pd.to_numeric(s, errors='coerce')

s = df1['Ind.Presión (PI8026)']
df1['Ind.Presión (PI8026)'] = pd.to_numeric(s, errors='coerce')

s = df1['Ind.Presión (PIC8025)']
df1['Ind.Presión (PIC8025)'] = pd.to_numeric(s, errors='coerce')

s = df1['Ind.Temperatura (TI8015)']
df1['Ind.Temperatura (TI8015)'] = pd.to_numeric(s, errors='coerce')

s = df1['Ind.Temperatura (TIC8014)']
df1['Ind.Temperatura (TIC8014)'] = pd.to_numeric(s, errors='coerce')

attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1

# %%
df1 = df1.fillna(method='ffill')

attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1

# %%
cond = ((df1['Fecha'].ge(pd.to_datetime('2016-01-01 00:00:00', format='%Y-%m-%d %H:%M:%S', errors='coerce'))))
df1 = df1[cond]
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1

# %%
df1 = df1
df1.set_index([
	'Fecha',
], inplace=True)
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1

# %%
cond = ((df1['Conductividad'].le(12)))
df1 = df1[cond]
attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1

# %%
from functools import partial
from pandas.tseries.frequencies import to_offset

def roundfunc(t, freq):
	freq = to_offset(freq)
	return pd.Timestamp((t.value // freq.delta.value) * freq.delta.value)

df1 = df1.groupby(partial(roundfunc, freq='120t'))

attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1
enum = enumerate(df1.groups)
nextel = next(enum)
nextel[1]
df1.get_group(nextel[1])
nextel = next(enum)
nextel[1]
df1.get_group(nextel[1])

# %%
df1 = df1.aggregate('median')

attrs = {
	'var': 'df1',
	'type': type(df1).__name__,
}
[attrs]
df1

# %%
file = os.path.join('C:/Users/manue/Downloads/', 'Rebolier_Depurado.csv')
df1.to_csv(file)
attrs = {
	'var': 'empty',
	'type': 'empty',
}
[attrs]
'csv file saved'

# %%
file = os.path.join('C:/Users/manue/Downloads/', 'Rebolier_Depurado.csv')
df12 = pd.read_csv(file, header=0)
attrs = {
	'var': 'df12',
	'type': type(df12).__name__,
}
[attrs]
df12

# %%
df12 = df12
s = df12['Fecha']
df12['Fecha'] = pd.to_datetime(s, errors='coerce')

s = df12['M014-Carga Motor']
df12['M014-Carga Motor'] = pd.to_numeric(s, errors='coerce')

s = df12['M015-Carga Motor']
df12['M015-Carga Motor'] = pd.to_numeric(s, errors='coerce')

s = df12['Ind.Presión (PI8026)']
df12['Ind.Presión (PI8026)'] = pd.to_numeric(s, errors='coerce')

s = df12['Ind.Presión (PIC8025)']
df12['Ind.Presión (PIC8025)'] = pd.to_numeric(s, errors='coerce')

s = df12['Ind.Temperatura (TI8015)']
df12['Ind.Temperatura (TI8015)'] = pd.to_numeric(s, errors='coerce')

s = df12['Ind.Temperatura (TIC8014)']
df12['Ind.Temperatura (TIC8014)'] = pd.to_numeric(s, errors='coerce')

attrs = {
	'var': 'df12',
	'type': type(df12).__name__,
}
[attrs]
df12

# %%
df12 = df12
df12.set_index([
	'Fecha',
], inplace=True)
attrs = {
	'var': 'df12',
	'type': type(df12).__name__,
}
[attrs]
df12

# %%
df21 = df12
cond = ((df21['Estado'].eq(1)))
df21['Estado'].mask(cond, other='Falla', inplace=True)

cond = ((df21['Estado'].eq(0)))
df21['Estado'].mask(cond, other='Operativo', inplace=True)

attrs = {
	'var': 'df21',
	'type': type(df21).__name__,
}
[attrs]
df21

# %%
cond = ((df21['Estado'].eq('Falla')))
df16 = df21[cond]
attrs = {
	'var': 'df16',
	'type': type(df16).__name__,
}
[attrs]
df16

# %%
cond = ((df21['Estado'].eq('Operativo')))
df17 = df21[cond]
attrs = {
	'var': 'df17',
	'type': type(df17).__name__,
}
[attrs]
df17

# %%
df18 = df12.drop([
	'Ind.Temperatura (TIC8014)',
	'Ind.Temperatura (TI8015)',
	'Ind.Presión (PIC8025)',
	'Ind.Presión (PI8026)',
	'M015-Carga Motor',
	'M014-Carga Motor',
], axis='columns')
attrs = {
	'var': 'df18',
	'type': type(df18).__name__,
}
[attrs]
df18

# %%
df19 = df12[[
	'Estado',
]]
attrs = {
	'var': 'df19',
	'type': type(df19).__name__,
}
[attrs]
df19

# %%
def datetime_window(dfx, dfy, dfy_total, scaler, size, periods, y_choose='last', ahead=''):
    catcolsx = dfx.select_dtypes(['category']).columns
    dfx[catcolsx] = dfx[catcolsx].apply(lambda x: x.cat.codes)

    catcolsy = dfy.select_dtypes(['category']).columns
    dfy[catcolsy] = dfy[catcolsy].apply(lambda x: x.cat.codes)

    catcolsy_total = dfy_total.select_dtypes(['category']).columns
    dfy_total[catcolsy_total] = dfy_total[catcolsy_total].apply(lambda x: x.cat.codes)

    ind = []
    x = []
    y = []

    def get_windows(win):
        if (win.shape[0] != periods):
            return np.nan
        
        if (y_choose == 'ahead'):
            wy = dfy.loc[win.index, :]
            try:
                wy = dfy_total.loc[wy.index[-1] + pd.Timedelta(ahead)]
                y.append(wy)

                wx = dfx.loc[win.index, :]
                x.append(wx)

                ind.append(win.index[0])
            except:
                pass
        else:
            wx = dfx.loc[win.index, :]
            x.append(wx)

            wy = dfy.loc[win.index, :]
            if (y_choose == 'last'):
                wy = wy.iloc[-1]
            elif (y_choose == 'first'):
                wy = wy.iloc[0]
            y.append(wy)

            ind.append(win.index[0])
        
        return np.nan

    dfx.iloc[:, 0].rolling(size).apply(get_windows)
    
    return x, y, ind

# --------------------------------------------------------------------------------------
def print_list_shape(lst):
    s = ''
    if (len(lst) > 0):
        s += str(len(lst))
        s += ' x ' + str(np.array(lst[0]).shape)
    else:
        s += 'empty'
        
    return s

# --------------------------------------------------------------------------------------
def normal_anomal_split(dfx, dfy, size, periods, y_choose='last', ahead='', custom_normal_split=False, normal_test_ratio=0.1, scaler='MinMaxScaler'):
    
    if (scaler == 'MinMaxScaler'):
        myscaler = MinMaxScaler(feature_range=(0, 1))
    elif (scaler == 'StandardScaler'):
        myscaler = StandardScaler()
    elif(scaler == 'RobustScaler'):
        myscaler = RobustScaler(with_centering=True, with_scaling=True, quantile_range=(25, 75))
    
    x_windowed, y_windowed, windows_ind = datetime_window(dfx=dfx, dfy=dfy, dfy_total=dfy, scaler=myscaler, size=size, periods=periods, y_choose=y_choose, ahead=ahead)
    
    
    x_normal = []
    y_normal = []
    x_anomal = []
    y_anomal = []
    for (i, wy) in enumerate(y_windowed):
        if wy.iloc[0] == 0:
            x_normal.append(x_windowed[i])
            y_normal.append(y_windowed[i])
        else:
            x_anomal.append(x_windowed[i])
            y_anomal.append(y_windowed[i])
    
    
    normal_indices = [i for i in range(len(x_normal))]
    normal_indices_permuted = np.random.permutation(normal_indices)
    
    length = len(x_normal)
    length_test = round(length * normal_test_ratio)
    
    if custom_normal_split:
        normal_test_indices = normal_indices_permuted[:length_test]
        normal_train_indices = normal_indices_permuted[length_test:]
    else:
        normal_test_indices = normal_indices_permuted[:len(y_anomal)]
        normal_train_indices = normal_indices_permuted[len(y_anomal):]
    
    
    x_normal_train = [x_normal[i] for i in normal_train_indices]
    x_normal_test = [x_normal[i] for i in normal_test_indices]
    
    
    x_normal_train_total = pd.concat(x_normal_train)
    x_normal_train_total = x_normal_train_total[~x_normal_train_total.index.duplicated(keep='first')]
    x_normal_train_total.sort_index(inplace=True)
    
    myscaler.fit(x_normal_train_total.to_numpy())
    
    x_train = []
    for wx in x_normal_train:
        wx = wx.to_numpy()
        wx = np.squeeze(myscaler.transform(wx))
        x_train.append(wx)
    
    
    x_test = []
    y_test = []
    for wx in x_normal_test:
        wx = wx.to_numpy()
        wx = np.squeeze(myscaler.transform(wx))
        x_test.append(wx)
        y_test.append(0)
        
    for wx in x_anomal:
        wx = wx.to_numpy()
        wx = np.squeeze(myscaler.transform(wx))
        x_test.append(wx)
        y_test.append(1)
    
    x_mix = []
    for wx in x_windowed:
        wx = wx.to_numpy()
        wx = np.squeeze(myscaler.transform(wx))
        x_mix.append(wx)
    
    y_mix = []
    for wy in y_windowed:
        wy = wy.to_numpy()
        wy = wy[0]
        y_mix.append(wy)
        
    i_mix = windows_ind

    
    return x_train, x_test, y_test, x_mix, y_mix, i_mix, myscaler
x_train, x_test, y_test, x_mix, y_mix, i_mix, myscaler = normal_anomal_split(
	dfx=df18, dfy=df19
	, size='12h', periods=6, y_choose='last', ahead=''
	, custom_normal_split=True, normal_test_ratio=0.2, scaler='MinMaxScaler')

df18 = {
	'x_train': np.array(x_train),
	'x_test': np.array(x_test),
	'y_test': np.array(y_test),
	'x_mix': np.array(x_mix),
	'y_mix': np.array(y_mix),
	'i_mix': i_mix,
	'myscaler': myscaler,
}

attrs = {
	'var': 'df18',
	'type': type(df18).__name__,
}
[attrs]

{
	'x_train': print_list_shape(x_train),
	'x_test': print_list_shape(x_test),
	'y_test': print_list_shape(y_test),
}

np.squeeze(df18['x_train'])
np.squeeze(df18['x_test'])
np.squeeze(df18['y_test'])

# %%
file = os.path.join('C:/Users/manue/Downloads/', 'Rebolier_Informe.NPZ')
np.savez(file, x_train=df18['x_train'], x_test=df18['x_test'], y_test=df18['y_test'], x_mix=df18['x_mix'], y_mix=df18['y_mix'], i_mix=df18['i_mix'])
scaler_file = os.path.join('C:/Users/manue/Downloads/', 'scaler.joblib')
joblib.dump(df18['myscaler'], scaler_file)
attrs = {
	'var': 'empty',
	'type': 'empty',
}
[attrs]
'npz file saved'
